# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Questions per store
# 1. Rating affects discount
# 2. Rating changing depending on sale price
# 3. The amount of products obtained by other companies
# 4. How much variety does each category have
# 5. Total amount of money saved based on discounted prices
# 6. Which categories' have more discounts? Does sub-category determine it as well? Brand maybe?
# 7. Above question but instead of dicounts change to reviews.
# 8. What category is reviewed the best or worse?
# 9. Does having more reviews have an affect on rating?
# 10. Sale Price range count
#
#
# Questions between stores
# 1. Which store has the most variety based on cateogires and sub?
# 2. Which store offers the best average discounts or consistent?
# 3. Which store produces the most of their own products or gets the most suppliers?
# 4. Which store has the better rating per item?
# 5.

# %% [markdown]
# ## At Home

# %%
at_home_df = pd.read_csv("Cleaned_Datasets/at_home_christmas_deco.csv", index_col=0)
at_home_df.head()
# Out:
#                                                Name  Actual Price  Sale Price  \
# 0  Premium Rolling Christmas Tree Storage Bag, 7.5'         24.99       24.99
# 1             Inflatable Colossal Waving Santa, 20'        199.99       99.99
# 2       & Elf Pets® Merry Christmas Table Decor, 6"          4.99        2.49
# 3     Christmas Magic Card Holder Table Decor, 11x7          9.99        4.99
# 4                   150-Count Silver Ornament Hooks          1.99        0.99
#
#    Discount %  Rating  Number of Reviews  \
# 0         0.0     4.2                 96
# 1        50.0     3.2                 23
# 2        50.0     0.0                  0
# 3        50.0     5.0                  1
# 4        50.0     4.1                 39
#
#                                 Category                     Sub-Category  \
# 0                              Christmas                Christmas Storage
# 1  Christmas Inflatables & Outdoor Decor                  Oversized Decor
# ...
