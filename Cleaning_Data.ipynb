# %%
import numpy as np
import pandas as pd

# %%
at_home_df = pd.read_csv("Datasets/at_home_christmas_deco.csv", index_col=False)
at_home_df.head()
# Out:
#    Unnamed: 0                                              Name Actual Price  \
# 0           0  Premium Rolling Christmas Tree Storage Bag, 7.5'       $69.99
# 1           1             Inflatable Colossal Waving Santa, 20'       $69.99
# 2           2       & Elf Pets® Merry Christmas Table Decor, 6"       $69.99
# 3           3     Christmas Magic Card Holder Table Decor, 11x7       $69.99
# 4           4                   150-Count Silver Ornament Hooks       $69.99
#
#   Sale Price Discount %  Rating  Number of Reviews  \
# 0     $24.99        64%     4.2                 96
# 1     $24.99        64%     3.2                 23
# 2     $24.99        64%     0.0                  0
# 3     $24.99        64%     5.0                  1
# 4     $24.99        64%     4.1                 39
#
#                                 Category Sub-Category                  Brand
# 0  Christmas Inflatables & Outdoor Decor  Porch Decor                    NaN
# ...

# %%
at_home_df.drop(columns=at_home_df.columns[0], axis=1, inplace=True)

# %%
at_home_df.head()
# Out:
#                                                Name Actual Price Sale Price  \
# 0  Premium Rolling Christmas Tree Storage Bag, 7.5'       $69.99     $24.99
# 1             Inflatable Colossal Waving Santa, 20'       $69.99     $24.99
# 2       & Elf Pets® Merry Christmas Table Decor, 6"       $69.99     $24.99
# 3     Christmas Magic Card Holder Table Decor, 11x7       $69.99     $24.99
# 4                   150-Count Silver Ornament Hooks       $69.99     $24.99
#
#   Discount %  Rating  Number of Reviews  \
# 0        64%     4.2                 96
# 1        64%     3.2                 23
# 2        64%     0.0                  0
# 3        64%     5.0                  1
# 4        64%     4.1                 39
#
#                                 Category Sub-Category                  Brand
# 0  Christmas Inflatables & Outdoor Decor  Porch Decor                    NaN
# 1  Christmas Inflatables & Outdoor Decor  Porch Decor                    NaN
# ...

# %%
at_home_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2228 entries, 0 to 2227
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               2228 non-null   object
#  1   Actual Price       2228 non-null   object
#  2   Sale Price         2228 non-null   object
#  3   Discount %         2228 non-null   object
#  4   Rating             2228 non-null   float64
#  5   Number of Reviews  2228 non-null   int64
#  6   Category           2228 non-null   object
#  7   Sub-Category       2228 non-null   object
#  8   Brand              1356 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 156.8+ KB

# %%
at_home_df.nunique()
# Out:
# Name                 2202
# Actual Price            1
# Sale Price              1
# Discount %              1
# Rating                 28
# Number of Reviews      47
# Category                1
# Sub-Category            1
# Brand                  16
# dtype: int64

# %%
target_df = pd.read_csv("Datasets/target_christmas_deco.csv", index_col=False)

# %%
target_df.drop(columns=at_home_df.columns[0], axis=1, inplace=True)

# %%
target_df.head()
# Out:
#                                                 Name Actual Price  \
# 0  Santa Fabric Christmas Figurine with Blue Gift...        $5.00
# 1  Shatter-Resistant Textured Plastic Christmas T...        $5.00
# 2  6pc Sisal Christmas Bottle Brush Tree Set - Wo...       $10.00
# 3  Medium Ornament Bottle Brush Christmas Tree - ...       $10.00
# 4  Shaped Christmas Tree Novelty Throw Pillow - W...       $10.00
#
#     Sale Price Discount %  Rating  Number of Reviews               Category  \
# 0  Not on Sale         0%     4.6                  9  Christmas Decorations
# 1  Not on Sale         0%     4.6                  9              Christmas
# 2  Not on Sale         0%     4.6                  9  Christmas Decorations
# 3  Not on Sale         0%     4.6                  9             Home Decor
# 4  Not on Sale         0%     4.6                  9                   Home
#
#                    Sub-Category       Brand
# 0  Indoor Christmas Decorations  Wondershop
# ...

# %%
at_home_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1120 entries, 0 to 1119
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1120 non-null   int64
#  1   Name               1120 non-null   object
#  2   Actual Price       1120 non-null   object
#  3   Sale Price         1120 non-null   object
#  4   Discount %         1120 non-null   object
#  5   Rating             1120 non-null   float64
#  6   Number of Reviews  1120 non-null   int64
#  7   Category           1120 non-null   object
#  8   Sub-Category       1120 non-null   object
#  9   Brand              1120 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 87.6+ KB

# %%
at_home_df.nunique()
# Out:
# Unnamed: 0           1120
# Name                 1108
# Actual Price          285
# Sale Price            226
# Discount %             54
# Rating                  1
# Number of Reviews       1
# Category                7
# Sub-Category           11
# Brand                  77
# dtype: int64
